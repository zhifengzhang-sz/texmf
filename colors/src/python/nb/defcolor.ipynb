# %%
from Latex.Utils import qicolormodel, definecolor, key2model, key2modeltext, colormaplist, colormaptext
from Color.database import PaletteDB
from Color.html import swatches, show_palette
from Images import mpl

# %%
palette=['#808080','#C0C0C0','#778899','#FDBC42','#778899','#0D0D0D']

# %%
print(qicolormodel('gray',palette))
# Out:
# \qicolormodel{gray}{808080}{C0C0C0}{778899}{FDBC42}{778899}{0D0D0D}

# %%
print(definecolor('primary','#C0C0C0'))
# Out:
# \definecolor[named]{primary}{HTML}{C0C0C0}

# %% [markdown]
# ## [Color code: 4574](https://colorpalettes.net/color-palette-4574/)
# Brown, combined with shades of yellow, is a rather unusual combination that can be called really sweet. It is both citrusy, caramel, and has a slight hint of cinnamon, which gives it a special versatility. In summer it will invigorate, make you act and move, and in winter it will warm and relax.
#
# Photo by Sara Cervera.

# %%
mpl.show_img_url(PaletteDB.palette_image_url(4566))

# %%
show_palette(PaletteDB.palette(4566))
# Out:
# <div style='width: 500px; overflow: auto; font-size: 10px;
#     font-weight: bold; text-align: center; line-height: 1.5;'>
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #180C0C;"></div>
#     <div>#180C0C</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #483948;"></div>
#     <div>#483948</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #B2AB2E;"></div>
#     <div>#B2AB2E</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #ED413E;"></div>
#     <div>#ED413E</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #EFB786;"></div>
#     <div>#EFB786</div>
# </div>
# </div>

# %%
key2model('4574',4574)
# Out:
# '\\qicolormodel{4574}{583E26}{A78B71}{F7C815}{EC9704}{9C4A1A}'

# %%
key2modeltext('4574',4574)
# Out:
# '\\qicolormodeltext{4574}{f2f3f4}{131516}{131516}{131516}{f2f3f4}'

# %% [markdown]
# ## [Color code: 4502](https://colorpalettes.net/color-palette-4502/)
# If you want to create an Indian style living room interior, then you should use a combination of warm pale yellow shades with cool purple tones. Believe me, the aroma of curry and oriental spices will definitely soar in the air, which will definitely help improve your mood and tune in a friendly way.
#
# Photo by Mona Eendra.

# %%
mpl.show_img_url(PaletteDB.palette_image_url(4502))

# %%
show_palette(PaletteDB.palette(4502))
# Out:
# <div style='width: 500px; overflow: auto; font-size: 10px;
#     font-weight: bold; text-align: center; line-height: 1.5;'>
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #BF8709;"></div>
#     <div>#BF8709</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #EAC57D;"></div>
#     <div>#EAC57D</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #B9BBDE;"></div>
#     <div>#B9BBDE</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #807490;"></div>
#     <div>#807490</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #523857;"></div>
#     <div>#523857</div>
# </div>
# </div>

# %%
key2model('4502',4502)
# Out:
# '\\qicolormodel{4502}{BF8709}{EAC57D}{B9BBDE}{807490}{523857}'

# %%
key2modeltext('4502',4502)
# Out:
# '\\qicolormodeltext{4502}{f2f3f4}{131516}{131516}{f2f3f4}{f2f3f4}'

# %% [markdown]
# ## [Color code: 4565](https://colorpalettes.net/color-palette-4565/)
# An invigorating, but at the same time soothing charge, which so many lack, this particular palette can give. The combination of cool shades of green and brown is an unusual contrast that clearly distinguishes between peace and vivacity, but at the same time creating coziness on cool autumn days.
#
# Photo by Linh Le.

# %%
mpl.show_img_url(PaletteDB.palette_image_url(4565))

# %%
show_palette(PaletteDB.palette(4565))
# Out:
# <div style='width: 500px; overflow: auto; font-size: 10px;
#     font-weight: bold; text-align: center; line-height: 1.5;'>
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #677C77;"></div>
#     <div>#677C77</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #445F3B;"></div>
#     <div>#445F3B</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #8EA076;"></div>
#     <div>#8EA076</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #E0EFEA;"></div>
#     <div>#E0EFEA</div>
# </div>
#
# <div style="float: left;">
#     <div style="width: 50px; height: 50px; background: #564734;"></div>
#     <div>#564734</div>
# </div>
# </div>

# %%
key2model('4565',4565)
# Out:
# '\\qicolormodel{4565}{677C77}{445F3B}{8EA076}{E0EFEA}{564734}'

# %%
key2modeltext('4565',4565)
# Out:
# '\\qicolormodeltext{4565}{f2f3f4}{f2f3f4}{131516}{131516}{f2f3f4}'

# %% [markdown]
# ## Defining list of palettes

# %%
keys=[4565,4502,4574]
print(colormaplist(keys))
# Out:
# colormap/.list={
# 	{4565(677C77,445F3B,8EA076,E0EFEA,564734)},
# 	{4502(BF8709,EAC57D,B9BBDE,807490,523857)},
# 	{4574(583E26,A78B71,F7C815,EC9704,9C4A1A)}}

# %%
print(colormaptext(keys))
# Out:
# colormapc/.list={
# 	{4565(f2f3f4,f2f3f4,131516,131516,f2f3f4)},
# 	{4502(f2f3f4,131516,131516,f2f3f4,f2f3f4)},
# 	{4574(f2f3f4,131516,131516,131516,f2f3f4)}}

# %% [markdown]
# ## Defining the entire palette dataset

# %%
keys=list(PaletteDB.palettes.keys())
print(colormaplist(keys))
# Out:
# colormap/.list={
# 	{587(d35002,ffa602,f9d692,c18e01,4f5819)},
# 	{3841(A05E2B,E0992C,F1EEA6,EBDDD2,F7F5F6)},
# 	{4405(274215,85BB4D,CAD8D8,EEA402,DD7236)},
# 	{4502(BF8709,EAC57D,B9BBDE,807490,523857)},
# 	{4507(6A3F36,C8A796,F4F3EE,F8E4BE,EEA988)},
# 	{4508(6A7793,CFD1E0,F9F7FA,D0C9D0,B4A8AA)},
# 	{4522(567A04,D4CF6D,D7A3B6,9783A9,54387F)},
# 	{4529(945D87,EDD1EC,EECC70,D71232,82071B)},
# 	{4530(D3B19E,D39CBD,995E7C,683142,312528)},
# 	{4552(BB35AE,E99FF4,EDE7F8,F5BB2C,D2B4AA)},
# 	{4555(3D5220,B7CB99,778FD2,2A3759,431D32)},
# 	{4558(5A7A0A,83D350,FAB036,FDD48A,513C2F)},
# 	{4561(338309,C9D46C,E48716,FAAB01,DFBCB2)},
# 	{4565(677C77,445F3B,8EA076,E0EFEA,564734)},
# 	{4566(180C0C,483948,B2AB2E,ED413E,EFB786)},
# 	{4571(217074,37745B,8B9D77,E7EAEF,EDC5AB)},
# 	{4572(AA1803,BD613C,F1BAA1,BCAF4D,6D8C00)},
# 	{4573(1A2902,344C11,778D45,AEC09A,AEC670)},
# 	{4574(583E26,A78B71,F7C815,EC9704,9C4A1A)}}

# %%
print(colormaptext(keys))
# Out:
# colormapc/.list={
# 	{587(f2f3f4,131516,131516,131516,f2f3f4)},
# 	{3841(f2f3f4,131516,131516,131516,131516)},
# 	{4405(f2f3f4,131516,131516,131516,f2f3f4)},
# 	{4502(f2f3f4,131516,131516,f2f3f4,f2f3f4)},
# 	{4507(f2f3f4,131516,131516,131516,131516)},
# 	{4508(f2f3f4,131516,131516,131516,131516)},
# 	{4522(f2f3f4,131516,131516,f2f3f4,f2f3f4)},
# 	{4529(f2f3f4,131516,131516,f2f3f4,f2f3f4)},
# 	{4530(131516,131516,f2f3f4,f2f3f4,f2f3f4)},
# 	{4552(f2f3f4,131516,131516,131516,131516)},
# 	{4555(f2f3f4,131516,131516,f2f3f4,f2f3f4)},
# 	{4558(f2f3f4,131516,131516,131516,f2f3f4)},
# 	{4561(f2f3f4,131516,131516,131516,131516)},
# 	{4565(f2f3f4,f2f3f4,131516,131516,f2f3f4)},
# 	{4566(f2f3f4,f2f3f4,131516,f2f3f4,131516)},
# 	{4571(f2f3f4,f2f3f4,131516,131516,131516)},
# 	{4572(f2f3f4,f2f3f4,131516,131516,f2f3f4)},
# 	{4573(f2f3f4,f2f3f4,f2f3f4,131516,131516)},
# 	{4574(f2f3f4,131516,131516,131516,f2f3f4)}}

# %%
PaletteDB.colorpalette_url(4405)
# Out:
# 'https://colorpalettes.net/color-palette-4405'
